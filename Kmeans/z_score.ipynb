# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import minmax_scale,MinMaxScaler , StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Data Science/Machine Learning/Campusx/Data/fruits.csv")

# %%
df = df[['sphericity','weight']]
df.describe()
# Out:
#        sphericity      weight
# count   60.000000   60.000000
# mean     0.820583  142.750000
# std      0.067577   23.352585
# min      0.710000  101.000000
# 25%      0.767250  124.000000
# 50%      0.823000  143.000000
# 75%      0.870500  164.000000
# max      0.947000  184.000000

# %%
df = pd.DataFrame(minmax_scale(df),columns= df.columns)

# %%
df.describe()
# Out:
#        sphericity     weight
# count   60.000000  60.000000
# mean     0.466596   0.503012
# std      0.285133   0.281356
# min      0.000000   0.000000
# 25%      0.241561   0.277108
# 50%      0.476793   0.506024
# 75%      0.677215   0.759036
# max      1.000000   1.000000

# %%
scaling = MinMaxScaler()
X_m = pd.DataFrame(scaling.fit_transform( df[['sphericity','weight']]),columns=[['sphericity','weight']])

# %%
((df.sphericity - df.sphericity.mean())/df.sphericity.std()).to_frame().describe()
# Out:
#          sphericity
# count  6.000000e+01
# mean  -1.036208e-16
# std    1.000000e+00
# min   -1.636416e+00
# 25%   -7.892288e-01
# 50%    3.576193e-02
# 75%    7.386688e-01
# max    1.870719e+00

# %%
# Standard Scaler Formula
((df.sphericity - df.sphericity.mean())/df.sphericity.std()).to_frame()
((df.weight - df.weight.mean())/df.weight.std()).to_frame()
# Out:
#       weight
# 0  -0.974196
# 1  -0.760087
# 2  -1.402414
# 3  -0.845731
# 4  -0.802909
# 5  -0.545978
# 6  -0.331869
# 7  -1.616523
# 8  -0.460334
# 9  -0.674444
# 10 -0.417513
# 11 -0.374691
# 12 -1.402414
# 13 -1.017018
# 14 -1.573702
# 15 -1.273949
# 16 -1.488058
# 17 -0.460334
# 18 -1.017018
# 19  0.010705
# 20 -1.787811
# 21  0.267636
# 22 -0.289047
# 23 -0.074938
# 24  0.096349
# 25 -1.445236
# 26 -1.488058
# 27  0.053527
# 28 -1.787811
# 29 -0.802909
# 30  0.481745
# 31  1.166894
# 32  0.909964
# 33  0.396102
# 34  1.252538
# 35  1.637934
# 36  1.295360
# 37  1.038429
# 38  1.766400
# 39  0.738676
# 40  1.338182
# 41  0.396102
# 42  1.252538
# 43  0.653033
# 44  1.124073
# 45  1.166894
# 46  0.909964
# 47  0.481745
# 48  0.267636
# 49  0.738676
# 50 -0.032116
# 51 -0.117760
# 52  0.952785
# 53  0.396102
# 54  1.038429
# 55  1.252538
# 56  0.010705
# 57  1.466647
# 58  0.824320
# 59 -0.117760

# %%
scaling = StandardScaler()
df_z =pd.DataFrame(scaling.fit_transform(df[['sphericity','weight']]),columns=['sphericity','weight'])

# %%
plt.scatter('sphericity','weight',data=df_z)
plt.plot()
# Out:
# []

# %%
plt.scatter('sphericity','weight',data=X_m)
plt.plot()
# Out:
# []
